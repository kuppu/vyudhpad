# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from datasets import load_dataset # For other datasets
from sentence_transformers import SentenceTransformer #to encode text to vectors
from qdrant_client import QdrantClient, models

import os
import time
import torch

from tqdm.auto import tqdm

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device != 'cuda':
    print('Sorry no cuda.')
else:
    print('Using CUDA-GPU')
    
encoderModel = SentenceTransformer('all-MiniLM-L6-v2', device=device) # Model to create embeddings
# Out:
# Using CUDA-GPU

# %%
query = 'Appendicectomy procedure'
xq = encoderModel.encode(query)
print(f'''The dimension of the vector is {xq.shape}''')
xq
# Out:
# The dimension of the vector is (384,)
# array([-1.41302152e-02,  5.11170365e-02, -7.05268141e-03, -4.34320606e-02,
#        -7.33532757e-02, -9.40867364e-02,  4.23129415e-03,  2.10136212e-02,
#        -1.14401393e-02,  4.96104881e-02,  7.46712685e-02,  4.05386835e-02,
#        -1.19351493e-02, -2.58628670e-02, -2.21027061e-02, -1.26899211e-02,
#         7.78764719e-03, -7.04822391e-02, -1.27317850e-02,  2.95674633e-02,
#         8.93106684e-03,  4.02070722e-03,  4.30439562e-02, -1.39735267e-02,
#         6.98572919e-02, -8.89082775e-02, -5.86595722e-02,  7.88074732e-02,
#         5.89536084e-03, -2.64904313e-02,  5.06862104e-02, -4.56224605e-02,
#        -1.56551059e-02, -3.91518660e-02,  8.18973854e-02, -1.62047090e-03,
#         2.55833939e-02,  6.93021342e-02, -4.90610115e-03,  1.30840018e-03,
#         4.78595607e-02, -1.97446961e-02, -2.30856631e-02,  2.22700536e-02,
#         2.88418438e-02, -3.77949141e-02, -6.07232861e-02, -4.13567014e-02,
#         3.97630297e-02,  5.00037670e-02, -3.59451771e-02, -6.08060360e-02,
#        -2.40867324e-02,  1.30132258e-01, -4.94422875e-02, -4.54271398e-03,
#        -1.68243870e-02, -1.02294628e-02, -6.37013540e-02, -5.70745505e-02,
#         9.22374148e-03,  3.91657874e-02,  1.12425757e-03,  5.33078723e-02,
#        -1.06455140e-01, -4.71899509e-02,  6.74539655e-02, -6.34932518e-02,
#        -3.18376832e-02,  1.33015299e-02,  2.99058519e-02, -6.21091239e-02,
#         1.22204861e-02, -1.74038578e-02, -4.40213569e-02, -7.47367740e-02,
#         4.34742607e-02,  1.05358148e-02, -6.24351390e-02,  6.30386099e-02,
#        -1.84608484e-03,  1.68539595e-03, -2.09474210e-02,  3.61587256e-02,
#        -2.13145632e-02, -3.08700670e-02,  6.77639339e-03, -8.82255193e-03,
#        -3.72667573e-02,  3.85044795e-03,  2.16256790e-02,  6.29625469e-02,
#         1.56285726e-02, -5.55065572e-02,  1.02631047e-01, -2.50477325e-02,
#        -4.38972861e-02, -6.03639968e-02, -4.16549705e-02, -6.95603993e-03,
#        -2.15561651e-02, -7.95590430e-02, -4.17342596e-02, -2.49034744e-02,
#         1.60422847e-02, -3.21225077e-02, -7.90493339e-02, -6.20635785e-02,
#         3.02538145e-02, -6.86935633e-02, -2.18277816e-02, -1.16075191e-03,
#         6.27164692e-02, -6.35799617e-02,  3.57187446e-03,  9.91267934e-02,
#         2.57751960e-02, -4.71008569e-03,  2.00360138e-02, -1.99823640e-02,
#        -6.39265776e-03,  7.41422698e-02,  4.21692012e-03,  3.14979181e-02,
#         6.10608123e-02, -4.90534492e-02,  5.63600250e-02,  3.73099565e-34,
#         1.52564850e-02, -7.36409500e-02, -1.67627558e-02,  3.12741473e-02,
#         5.60541861e-02,  1.00676887e-01, -1.35586243e-02,  4.71636793e-03,
#        -4.10364419e-02, -1.40530348e-01, -6.01064265e-02,  8.17024149e-03,
#         2.11522803e-02, -7.39059737e-03, -1.76936928e-02,  2.16316208e-02,
#        -4.64065932e-02,  1.52390391e-01, -1.50473639e-02,  5.63972779e-02,
#        -3.89499194e-03, -1.58394333e-02,  3.14136483e-02,  1.30533297e-02,
#         3.58436406e-02,  9.48810950e-02, -9.07713268e-03,  1.37425130e-02,
#         3.79849486e-02, -1.25158252e-02, -2.16915341e-05,  1.66996308e-02,
#         3.64588648e-02, -2.78885593e-03, -9.15963575e-02,  2.39137858e-02,
#         8.00588075e-03, -1.78959314e-02,  7.24394992e-02,  5.11628129e-02,
#        -2.09665243e-02,  3.06801479e-02,  4.81466837e-02,  5.52200787e-02,
#        -8.05136785e-02, -3.34401578e-02,  3.20765786e-02,  8.14733002e-03,
#         6.56206533e-02,  5.97186433e-03,  2.90122796e-02,  3.50956358e-02,
#         9.75388214e-02, -2.94315573e-02, -3.73387188e-02,  4.35831398e-02,
#         3.53149362e-02,  1.26975141e-02,  3.08261886e-02, -5.94237931e-02,
#         5.15903346e-02,  7.63096940e-03, -3.38329258e-03,  4.95576039e-02,
#        -3.35537493e-02, -2.89625162e-03,  5.43468371e-02, -2.52730586e-02,
#         5.69159649e-02, -4.11514863e-02, -1.22919463e-01,  2.05220841e-02,
#         9.58452001e-02,  5.27688153e-02, -5.90078942e-02,  5.30989766e-02,
#        -7.69871101e-02, -7.09839091e-02,  1.11955479e-02, -9.92249399e-02,
#        -1.20151564e-02, -1.42507302e-02,  1.69373304e-02, -8.70929565e-03,
#         1.26270220e-01,  1.00985095e-02, -1.14499733e-01,  2.46161055e-02,
#         2.79342774e-02,  3.79744880e-02, -6.22621290e-02,  2.31864974e-02,
#        -1.74820311e-02, -1.02589186e-02,  2.76295803e-02, -1.96839964e-33,
#         1.06508948e-01, -1.91441178e-02, -3.58957388e-02,  6.60321862e-03,
#         1.20953319e-03, -1.68211050e-02, -4.62115668e-02,  8.01801533e-02,
#        -4.60946560e-02, -3.71225439e-02, -7.18923211e-02,  1.38503117e-02,
#         4.22626920e-02, -4.82015237e-02, -2.30113603e-03,  6.09915424e-03,
#        -4.12267111e-02,  1.54003799e-02, -1.70957223e-02,  3.37578123e-03,
#         5.50447404e-03, -1.65449630e-03,  1.02986775e-01, -8.50291327e-02,
#        -6.19277731e-02, -4.80765030e-02,  3.70398201e-02, -4.82293516e-02,
#        -3.40995155e-02, -8.99477378e-02, -1.83556471e-02, -5.01912460e-02,
#        -2.15267260e-02, -3.91068570e-02,  6.58348426e-02,  8.36234912e-02,
#         2.64053401e-02, -4.62563932e-02,  3.64049301e-02, -1.92490406e-02,
#         4.36012298e-02, -1.01997443e-01, -1.70319732e-02,  8.71724486e-02,
#        -1.29546840e-02, -2.67025270e-02, -4.60737757e-02,  2.80833188e-02,
#         8.57957527e-02, -2.71588601e-02, -8.78107399e-02,  2.29010191e-02,
#        -1.72869787e-02,  2.51980294e-02,  6.19830228e-02, -4.66644652e-02,
#         2.15898603e-02, -6.08279891e-02, -4.46261354e-02, -9.84346773e-03,
#        -2.70623975e-02,  1.97042022e-02,  8.44179913e-02, -6.34592474e-02,
#         9.46175531e-02,  1.10222809e-01, -2.20120400e-02, -6.42125458e-02,
#        -6.69819713e-02,  6.47417605e-02, -4.76489291e-02, -2.85805203e-02,
#        -1.30229682e-01, -4.42057997e-02,  1.72912702e-02,  6.33171052e-02,
#         8.57800841e-02, -6.64173514e-02, -1.61270872e-02,  3.88764851e-02,
#        -3.14366519e-02, -5.71568310e-02,  7.02206418e-02,  1.55518670e-02,
#        -3.51119190e-02, -7.50274956e-02,  3.54914628e-02, -3.31621543e-02,
#        -7.88101926e-02, -4.12471555e-02,  8.31408799e-02,  4.27472219e-02,
#         9.29174870e-02,  2.96141729e-02, -4.77346033e-02, -1.64918106e-08,
#        -3.73630710e-02,  2.52228361e-02, -4.75606918e-02, -4.29426245e-02,
#        -4.52023000e-02, -1.65187940e-01,  4.61159982e-02,  9.11861807e-02,
#         2.94839256e-02, -7.97366947e-02, -4.48460840e-02,  3.84407789e-02,
#         1.39297955e-02,  2.79516019e-02, -4.93117869e-02, -3.59785780e-02,
#        -7.00065717e-02,  2.64300853e-02,  3.57800187e-03, -1.62998475e-02,
#        -6.15450740e-02, -4.75754179e-02, -4.83202040e-02, -1.09905982e-02,
#         7.33247548e-02,  8.86903852e-02, -6.87452219e-03,  1.33395689e-02,
#        -5.44911325e-02,  7.67377540e-02,  3.82051393e-02, -2.62181517e-02,
#         5.71528710e-02,  7.30642900e-02,  1.19990474e-02, -2.71606762e-02,
#         1.69238225e-02,  8.10527354e-02,  9.52529237e-02, -5.05436808e-02,
#         9.07592252e-02,  1.94352530e-02,  4.18788716e-02, -9.60980169e-03,
#         7.05861486e-04,  7.91072752e-03, -6.93010688e-02,  1.39984954e-02,
#        -4.40270528e-02,  8.92319083e-02,  4.68064733e-02, -4.76115430e-03,
#         2.28047930e-02, -1.42014362e-02,  3.11992541e-02,  3.80956791e-02,
#         5.29703163e-02,  3.64898331e-03,  2.59951800e-02,  1.37004599e-01,
#         3.58817652e-02,  7.10914377e-03,  6.89026639e-02, -3.83391529e-02],
#       dtype=float32)

# %%
qdrant = QdrantClient("http://localhost:6333")

# %%
collectionInfo =  None
try:
    collectionInfo = qdrant.get_collection(collection_name="HospitalCharges")
except:
    print('Exception found')
    
    
collectionInfo
# Out:
# CollectionInfo(status=<CollectionStatus.GREEN: 'green'>, optimizer_status=<OptimizersStatusOneOf.OK: 'ok'>, vectors_count=0, indexed_vectors_count=0, points_count=0, segments_count=8, config=CollectionConfig(params=CollectionParams(vectors=VectorParams(size=384, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None), shard_number=1, sharding_method=None, replication_factor=1, write_consistency_factor=1, read_fan_out_factor=None, on_disk_payload=True, sparse_vectors=None), hnsw_config=HnswConfig(m=16, ef_construct=100, full_scan_threshold=10000, max_indexing_threads=0, on_disk=False, payload_m=None), optimizer_config=OptimizersConfig(deleted_threshold=0.2, vacuum_min_vector_number=1000, default_segment_number=0, max_segment_size=None, memmap_threshold=None, indexing_threshold=20000, flush_interval_sec=5, max_optimization_threads=1), wal_config=WalConfig(wal_capacity_mb=32, wal_segments_ahead=0), quantization_config=None), payload_schema={})

# %%
# Create collection to store questions

#Carefull not to recreate collection every time
if not collectionInfo:
    qdrant.recreate_collection(
        collection_name="HospitalCharges",
        vectors_config=models.VectorParams(
            size=encoderModel.get_sentence_embedding_dimension(), # Vector size is defined by used model
            distance=models.Distance.COSINE
        )
    )

# %%
name_of_dir = '..\\..\\Data\\HospitalCharges\\'
# Storing list of all files 
# in the given directory in list_of_files 
list_of_files = filter( lambda x: os.path.isfile 
                       (os.path.join(name_of_dir, x)), 
                        os.listdir(name_of_dir) ) 
  
# Sort list of file names by size  
list_of_files = sorted( list_of_files, 
                        key =  lambda x: os.stat 
                       (os.path.join(name_of_dir, x)).st_size) 
  
# Iterate over sorted list of file  
# names and print them along with size one by one  
for name_of_file in list_of_files: 
    path_of_file = os.path.join(name_of_dir, name_of_file) 
    size_of_file  = os.stat(path_of_file).st_size  
    print(size_of_file/(1024*1024), 'MBytes -->', name_of_file)

# %%
#Read the file into a dataframe
for filename in filenames:
    if filename.endswith(".zip"):
        file2load = os.path.join(dirname, filename)
        print(file2load)

# %%
## Read the zip files containing Hosiptal Charge Data into a dataframe
df = pd.read_csv('..\\..\\Data\\HospitalCharges\\042104691_Marthas-Vineyard-Hospital_StandardCharges.zip', 
                 sep='|', encoding='latin', low_memory=False, on_bad_lines='warn')

df.rename(columns={'procedure': 'procedurename', 'contract': 'contractname'}, inplace=True)
(df.dtypes)
# Out:
# facility_id                    int64
# facility_name                 object
# procedurename                 object
# code_type                     object
# code                          object
# min_ip_reimb                 float64
# max_ip_reimb                 float64
# min_op_reimb                 float64
# max_op_reimb                 float64
# ndc                           object
# rev_code                      object
# procedure_description         object
# quantity                      object
# payer                         object
# contractname                  object
# plan                          object
# ip_price                     float64
# ip_pricing_detail             object
# ip_expected_reimbursement    float64
# ip_xr_detail                  object
# op_price                     float64
# op_pricing_detail             object
# op_expected_reimbursement    float64
# op_xr_detail                  object
# dtype: object

# %%
#Subset dataframe to include procedure_description and additonal fields for metadata
dfData = df[['facility_id', 'procedurename', 'procedure_description', 'payer', 'contractname', 'plan', 
               'ip_pricing_detail', 'ip_xr_detail', 'ip_price', 'ip_expected_reimbursement']]

dfData = dfData.fillna('')

# %%
dfData
# Out:
#         facility_id procedurename  \
# 0           1011999        331035
# 1           1011999      30000736
# 2           1011999      31000821
# 3           1011999        528969
# 4           1011999        119834
# ...             ...           ...
# 444501      1011999         97371
# 444502      1011999      76000021
# 444503      1011999      76001906
# 444504      1011999        460867
# 444505      1011999        448793
#
#                                     procedure_description  \
# 0       SET CHANNEL SEAL ENDOSCOPIC INSTRUMENT ROD LEN...
# 1                                               Vitamin K
# 2         Prenatal Known Familial Mutation (Includes Mcc)
# 3           HAND PLATE 0.8MM 10 HOLE COMPRESSION STRAIGHT
# 4                 HYDROMORPHONE 1 MG/ML INJECTION SYRINGE
# ...                                                   ...
# 444501             VANCOMYCIN 750 MG INTRAVENOUS SOLUTION
# 444502                 Debride/Remove FB Skin/Muscle/Bone
# 444503                      Stab Phlebetomy <10 Incisions
# 444504  CATHETER FOLEY 16 FRIN BARDEX IC BACTI GUARD A...
# 444505  KIT SET COLLECTION DRAPE FLUID SURGICAL DOLPHI...
#
#                                    payer  \
# 0                          HUMANA [1012]
# 1                           CIGNA [1006]
# 2             TUFTS HEALTH PLAN [170001]
# 3             TUFTS HEALTH PLAN [170001]
# 4       TUFTS HEALTH PUBLIC PLANS [1013]
# ...                                  ...
# 444501          HARVARD PILGRIM [120001]
# 444502         HEALTH NEW ENGLAND [1034]
# 444503                     HUMANA [1012]
# 444504                      AETNA [1001]
# 444505                      AETNA [1001]
#
#                                    contractname  \
# 0                         HB MVH MEDICARE [434]
# 1                  HB MVH CIGNA HMO / PPO [273]
# 2       HB MVH TUFTS HMO / PPO / CARELINK [327]
# 3       HB MVH TUFTS HMO / PPO / CARELINK [327]
# 4                         HB MVH MEDICAID [254]
# ...                                         ...
# 444501        HB MVH HPHC HMO / POS / PPO [329]
# 444502                    HB MVH MEDICAID [254]
# 444503                       HB MGB HUMANA [39]
# 444504              HB MGB AETNA INDEMNITY [31]
# 444505                    HB MVH MEDICARE [434]
#
#                                                      plan  \
# 0                HUMANA HMO MEDICARE REPLACEMENT [101201]
# 1                                  CIGNA HMO POS [100602]
# 2                           TUFTS CARELINK PPO [17000101]
# 3                           TUFTS CARELINK PPO [17000101]
# 4       TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [10...
# ...                                                   ...
# 444501           HPHC QUALITY LIMITED NTWK HMO [12000101]
# 444502         HEALTH NEW ENGLAND CONNECTOR CARE [103102]
# 444503                            HUMANA PPO POS [101202]
# 444504                           AETNA INDEMNITY [100102]
# 444505            AETNA PPO MEDICARE REPLACEMENT [100103]
#
#                                        ip_pricing_detail  \
# 0       Inv Loc: 3061000003; from OR location 3061000003
# 1                                      FSC: 296; BFG: 52
# 2                                  FSC: 48; Median of: 1
# 3       Inv Loc: 3061000003; from OR location 3061000003
# 4                        PHR: 4080000631; CHG: 408000007
# ...                                                  ...
# 444501                   PHR: 4080000631; CHG: 408000007
# 444502                                 FSC: 296; BFG: 52
# 444503                             FSC: 48; Median of: 1
# 444504  Inv Loc: 3061000003; from OR location 3061000003
# 444505  Inv Loc: 3061000003; from OR location 3061000003
#
#                                              ip_xr_detail  ip_price  \
# 0                                     No historical claim      0.00
# 1                Inpatient / Outpatient PAF; 91.4% Billed    184.00
# 2            Inpatient / Outpatient HMO PAF; 74.8% Billed   1521.00
# 3            Inpatient / Outpatient PPO PAF; 76.2% Billed   1338.00
# 4                                No contract line matched      4.83
# ...                                                   ...       ...
# 444501          Inpatient / Outpatient PAF; 78.18% Billed     26.62
# 444502      No historical claim; No contract line matched   2025.00
# 444503             Inpatient / Outpatient PAF; 92% Billed   2548.00
# 444504  No historical claim; Inpatient / Outpatient In...      0.00
# 444505                                No historical claim      0.00
#
#         ip_expected_reimbursement
# 0                            0.00
# 1                          168.18
# 2                         1137.71
# 3                         1019.56
# 4                            0.00
# ...                           ...
# 444501                      20.81
# 444502                       0.00
# 444503                    2344.16
# 444504                       0.00
# 444505                       0.00
#
# [444506 rows x 10 columns]

# %%
#convert data frame into json_list
json_list = [dict(v) for _, v in dfData.iterrows()]

# %%
json_list
# Out:
# [{'facility_id': 1011999,
#   'procedurename': '331035',
#   'procedure_description': 'SET CHANNEL SEAL ENDOSCOPIC INSTRUMENT ROD LENS SCOPE OUTFLOW MYOSURE BX/10EA',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30000736',
#   'procedure_description': 'Vitamin K',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA HMO / PPO [273]',
#   'plan': 'CIGNA HMO POS [100602]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed',
#   'ip_price': 184.0,
#   'ip_expected_reimbursement': 168.18},
#  {'facility_id': 1011999,
#   'procedurename': '31000821',
#   'procedure_description': 'Prenatal Known Familial Mutation (Includes Mcc)',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'TUFTS CARELINK PPO [17000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 1521.0,
#   'ip_expected_reimbursement': 1137.71},
#  {'facility_id': 1011999,
#   'procedurename': '528969',
#   'procedure_description': 'HAND PLATE 0.8MM 10 HOLE COMPRESSION STRAIGHT',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'TUFTS CARELINK PPO [17000101]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed',
#   'ip_price': 1338.0,
#   'ip_expected_reimbursement': 1019.56},
#  {'facility_id': 1011999,
#   'procedurename': '119834',
#   'procedure_description': 'HYDROMORPHONE 1 MG/ML INJECTION SYRINGE',
#   'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 4.83,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '27000353',
#   'procedure_description': 'HC Kafo Double Upright Free Knee/Ankle Cust Tier1',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS HMO [316]',
#   'plan': 'BLUE CROSS MA HMO POS [11000103]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 2246.0,
#   'ip_expected_reimbursement': 1522.34},
#  {'facility_id': 1011999,
#   'procedurename': '27000457',
#   'procedure_description': 'Heel Thomas With Wedge T1',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS PPO [317]',
#   'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 46.0,
#   'ip_expected_reimbursement': 31.18},
#  {'facility_id': 1011999,
#   'procedurename': '307472',
#   'procedure_description': 'SCREW BONE 20X3MM CANCELLOUS SS NONLOCKING LOW PROFILE',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]',
#   'plan': 'BLUE CROSS MA INDEMNITY [11000104]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 105.0,
#   'ip_expected_reimbursement': 71.17},
#  {'facility_id': 1011999,
#   'procedurename': '31000926',
#   'procedure_description': 'Amyotrophic Lateral Sclerosis (Ngs405)',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 2960.0,
#   'ip_expected_reimbursement': 2214.08},
#  {'facility_id': 1011999,
#   'procedurename': '77100017',
#   'procedure_description': 'Admin of Flumist Influenza Vaccine',
#   'payer': 'PHCS MULTIPLAN [1022]',
#   'contractname': 'HB MVH PHCS [332]',
#   'plan': 'GENERIC PHCS MULTIPLAN [102201]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient PAF; 91% Billed',
#   'ip_price': 30.0,
#   'ip_expected_reimbursement': 27.3},
#  {'facility_id': 1011999,
#   'procedurename': '81452',
#   'procedure_description': 'HIP STEM 8.5MM CENTRALIZER CEMENTRALIZER POLYMER PROSTALAC',
#   'payer': 'PHCS MULTIPLAN [1022]',
#   'contractname': 'HB MVH PHCS [332]',
#   'plan': 'GENERIC PHCS MULTIPLAN [102201]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient PAF; 91% Billed',
#   'ip_price': 150.0,
#   'ip_expected_reimbursement': 136.5},
#  {'facility_id': 1011999,
#   'procedurename': '76000142',
#   'procedure_description': 'Rpr Lac Cplx Trunk Ea Add 5cm',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]',
#   'plan': 'BLUE CROSS MA INDEMNITY [11000104]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 1472.0,
#   'ip_expected_reimbursement': 997.72},
#  {'facility_id': 1011999,
#   'procedurename': '90000120',
#   'procedure_description': 'Sbsq Hospital IP/Obs Care Mod Mdm 35 Minutes',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient PAF; 44.9% Billed',
#   'ip_price': 207.0,
#   'ip_expected_reimbursement': 92.94},
#  {'facility_id': 1011999,
#   'procedurename': '75000163',
#   'procedure_description': 'Colonoscopy Stoma W/Snare',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient PAF; 44.9% Billed',
#   'ip_price': 2417.0,
#   'ip_expected_reimbursement': 1085.23},
#  {'facility_id': 1011999,
#   'procedurename': '76000025',
#   'procedure_description': 'Debride Skin/Subq Tissue',
#   'payer': 'COMMONWEALTH CARE ALLIANCE [1007]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 129.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76000689',
#   'procedure_description': 'Apply Cast Shoulder to Hips 1',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 992.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30002892',
#   'procedure_description': 'HC Gold (Drug/Substance Definitive Qual/Quant Nos 1-3)',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 337.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76001549',
#   'procedure_description': 'Inject Anes Ganglion Stellate',
#   'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 2239.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '63600082',
#   'procedure_description': 'Chorionic Gonadotropin 1000u',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 15.17,
#   'ip_expected_reimbursement': 15.17},
#  {'facility_id': 1011999,
#   'procedurename': '31000117',
#   'procedure_description': 'Thawing & Expansion Frozen Cell',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]',
#   'plan': 'BLUE CROSS MA INDEMNITY [11000104]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 155.0,
#   'ip_expected_reimbursement': 105.06},
#  {'facility_id': 1011999,
#   'procedurename': '27000110',
#   'procedure_description': 'Implant Wrist / Finger T1',
#   'payer': '<Self-pay>',
#   'contractname': '<Self-pay>',
#   'plan': '<Self-pay>',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': '',
#   'ip_price': 2925.48,
#   'ip_expected_reimbursement': 2194.11},
#  {'facility_id': 1011999,
#   'procedurename': '30002175',
#   'procedure_description': 'Mgh Spec Ige Quan Semiquan Ea Allg',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient PAF; 44.9% Billed',
#   'ip_price': 81.0,
#   'ip_expected_reimbursement': 36.37},
#  {'facility_id': 1011999,
#   'procedurename': '83494',
#   'procedure_description': 'DEPRESSOR TONGUE 6.0IN WOOD SENIOR BX/100EA - DISCONTINUED PER MFG CONVERTED TO PS # 331901',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30003773',
#   'procedure_description': 'Voltage-Gated Calcium Channel Antibody Each',
#   'payer': 'COMMONWEALTH CARE ALLIANCE [1007]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 149.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30002006',
#   'procedure_description': 'Mgh Ala D and Porpho Deam RBC',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]',
#   'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed',
#   'ip_price': 285.0,
#   'ip_expected_reimbursement': 257.61},
#  {'facility_id': 1011999,
#   'procedurename': '76000020',
#   'procedure_description': 'Debride/Remove FB Skin/Subq/Muscle',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS PPO [317]',
#   'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 1908.0,
#   'ip_expected_reimbursement': 1293.24},
#  {'facility_id': 1011999,
#   'procedurename': '76001723',
#   'procedure_description': 'Atherectomy Iliac Open/Perc W/S&I',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]',
#   'plan': 'MGBHP HMO [15000102]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 71.5% Billed',
#   'ip_price': 16794.0,
#   'ip_expected_reimbursement': 12007.71},
#  {'facility_id': 1011999,
#   'procedurename': '76001708',
#   'procedure_description': 'US Inj Cervical Thoracic 2 Level',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]',
#   'plan': 'MGBHP PPO [15000107]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 75.1% Billed',
#   'ip_price': 385.0,
#   'ip_expected_reimbursement': 289.14},
#  {'facility_id': 1011999,
#   'procedurename': '63601332',
#   'procedure_description': 'HC Sculptra per 0.5 Mg',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 1.86,
#   'ip_expected_reimbursement': 1.39},
#  {'facility_id': 1011999,
#   'procedurename': '32687',
#   'procedure_description': 'SCREW BONE 16.0X4.5MM CORTEX SS STANDARD LG HEXAGONAL SOCKET FLAT HEAD',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MGB CIGNA INDEMNITY [32]',
#   'plan': 'CIGNA INDEMNITY [100603]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 149.85,
#   'ip_expected_reimbursement': 149.85},
#  {'facility_id': 1011999,
#   'procedurename': '498805',
#   'procedure_description': 'LUBRICANT INSTRUMENT 3G SURGILUBE BACTERIOSTATIC BX/144EA',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '93752',
#   'procedure_description': 'SCREW BONE 46.0X2.7MM CORTEX SS LOCKING SELF TAPPING FULL THREAD T8 STARDRIVE RECESS',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MGB HUMANA [39]',
#   'plan': 'HUMANA PPO POS [101202]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 92% Billed',
#   'ip_price': 253.08,
#   'ip_expected_reimbursement': 232.83},
#  {'facility_id': 1011999,
#   'procedurename': '50856',
#   'procedure_description': 'CONTAINER IV 1000ML EVACUATED GLASS BOTTLE RUBBER STOPPER CS/6EA',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30002963',
#   'procedure_description': 'HC Acetaminophen (Analgesics Non-Opioid 1 or 2)',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 128.0,
#   'ip_expected_reimbursement': 128.0},
#  {'facility_id': 1011999,
#   'procedurename': '61000079',
#   'procedure_description': 'MRI Breast Unilat W/O Cont',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 3386.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '27000355',
#   'procedure_description': 'HC Kafo Static Plastic Ped Prefabricated Tier1',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 137.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '62400020',
#   'procedure_description': 'Mgh G120143 Roadstr/Michi Neurosys',
#   'payer': '<Self-pay>',
#   'contractname': '<Self-pay>',
#   'plan': '<Self-pay>',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': '',
#   'ip_price': 1.0,
#   'ip_expected_reimbursement': 0.75},
#  {'facility_id': 1011999,
#   'procedurename': '27000007',
#   'procedure_description': 'Implant Anchor T1',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS PPO [317]',
#   'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 1143.14,
#   'ip_expected_reimbursement': 774.82},
#  {'facility_id': 1011999,
#   'procedurename': '476057',
#   'procedure_description': 'SET TUBING 9IN IV EXTENSION ALARIS SMBORE SPIN MALE LUER LOCK DISPOSALBE CS/100EA',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '48000152',
#   'procedure_description': 'Ep Intra-Atrial Pacing',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA HMO / PPO [273]',
#   'plan': 'CIGNA HMO POS [100602]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 91.4% Billed',
#   'ip_price': 2635.0,
#   'ip_expected_reimbursement': 2408.39},
#  {'facility_id': 1011999,
#   'procedurename': '436700',
#   'procedure_description': 'SHEARS W/ ADAPTIVE TISSUE TECHNOLOGY HARMONIC FOCUS+ BX/6 - DISCONTINUED USE PS # 548296',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH HPHC HMO / POS / PPO [329]',
#   'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '203791',
#   'procedure_description': 'FAM-TRASTUZUMAB DERUXTECAN-NXKI 100 MG INTRAVENOUS SOLUTION',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 7946.67,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '27000064',
#   'procedure_description': 'Catheter Intraspinal T1',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 2239.76,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76000911',
#   'procedure_description': 'Repair Vessel in-Abd',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'TUFTS CARELINK PPO [17000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 33035.0,
#   'ip_expected_reimbursement': 24710.18},
#  {'facility_id': 1011999,
#   'procedurename': '76000895',
#   'procedure_description': 'Repair Aneur Abd Iliac Rupt',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS HMO [316]',
#   'plan': 'BLUE CROSS MA HMO POS [11000103]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 52894.0,
#   'ip_expected_reimbursement': 35851.55},
#  {'facility_id': 1011999,
#   'procedurename': '30001359',
#   'procedure_description': 'Drug Susceptability Genotypic/Pheno',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 1274.0,
#   'ip_expected_reimbursement': 952.95},
#  {'facility_id': 1011999,
#   'procedurename': '32000327',
#   'procedure_description': 'Xr Aortogram Thoracic W/Ser S&I',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 8867.0,
#   'ip_expected_reimbursement': 8867.0},
#  {'facility_id': 1011999,
#   'procedurename': '27000383',
#   'procedure_description': 'HC Add Lower Extremity Long Tongue Stirrup Tier1',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 290.0,
#   'ip_expected_reimbursement': 290.0},
#  {'facility_id': 1011999,
#   'procedurename': '130523',
#   'procedure_description': 'SCREW BONE 10X2.0MM CORTEX SS SELF TAPPING FULL THREAD T6 STARDRIVE RECESS',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]',
#   'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed',
#   'ip_price': 129.87,
#   'ip_expected_reimbursement': 117.39},
#  {'facility_id': 1011999,
#   'procedurename': '99900342',
#   'procedure_description': 'R&B - Respite Care Sp',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]',
#   'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 90.39% Billed',
#   'ip_price': 425.0,
#   'ip_expected_reimbursement': 384.16},
#  {'facility_id': 1011999,
#   'procedurename': '76000660',
#   'procedure_description': 'Tx Fx Sesamoid Closed',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'BLUE CROSS MA MEDICARE HMO BLUE REPLACEMENT [11000107]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 675.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30001400',
#   'procedure_description': 'Hla Class II Semi-Quant Panel',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient PAF; 44.9% Billed',
#   'ip_price': 5048.0,
#   'ip_expected_reimbursement': 2266.55},
#  {'facility_id': 1011999,
#   'procedurename': '21045',
#   'procedure_description': 'LEUPROLIDE 22.5 MG (3 MONTH) INTRAMUSCULAR SYRINGE KIT',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'Inpatient PAF; 44.9% Billed',
#   'ip_price': 1351.38,
#   'ip_expected_reimbursement': 606.77},
#  {'facility_id': 1011999,
#   'procedurename': '36000166',
#   'procedure_description': 'Expl Retroperitoneum W/WO Bx Spx',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 5925.0,
#   'ip_expected_reimbursement': 4431.9},
#  {'facility_id': 1011999,
#   'procedurename': '62400267',
#   'procedure_description': 'G160156 Promise III Trial 2022p002366',
#   'payer': 'SENIOR WHOLE HEALTH [1014]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 62500.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '9259',
#   'procedure_description': 'BENZTROPINE 1 MG/ML INJECTION SOLUTION',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH HPHC HMO / POS / PPO [329]',
#   'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed',
#   'ip_price': 131.27,
#   'ip_expected_reimbursement': 102.63},
#  {'facility_id': 1011999,
#   'procedurename': '32000289',
#   'procedure_description': 'Xr Venogram Adrenal Bilat',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH HPHC HMO / POS / PPO [329]',
#   'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 78.18% Billed',
#   'ip_price': 9044.0,
#   'ip_expected_reimbursement': 7070.6},
#  {'facility_id': 1011999,
#   'procedurename': '76002334',
#   'procedure_description': 'Perc Decompression Pneumoperitoneum',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA HMO / PPO [273]',
#   'plan': 'CIGNA HMO POS [100602]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed',
#   'ip_price': 2591.0,
#   'ip_expected_reimbursement': 2368.17},
#  {'facility_id': 1011999,
#   'procedurename': '365184',
#   'procedure_description': 'WRIST PLATE 5 HOLE BONE VOLAR BRING LT 4 DISTAL PEGS',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]',
#   'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed',
#   'ip_price': 3555.0,
#   'ip_expected_reimbursement': 3213.36},
#  {'facility_id': 1011999,
#   'procedurename': '27000319',
#   'procedure_description': 'HC Hip Ortho Abd Stat W/Bar Thigh Cuffs Cstm Tier1',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'MGBHP CONNECTORCARE NON MGB PCP [15000106]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 618.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '307481',
#   'procedure_description': 'BIT DRILL 130X2.6MM BONE CANNULATED ANKLE FRACTURE MGMT SYSTEM',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30001399',
#   'procedure_description': 'Hla Class I Semi-Quantitative Panel',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA HMO / PPO [273]',
#   'plan': 'CIGNA HMO POS [100602]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed',
#   'ip_price': 5615.0,
#   'ip_expected_reimbursement': 5132.11},
#  {'facility_id': 1011999,
#   'procedurename': '76000140',
#   'procedure_description': 'Rpr Lac Cplx Trunk 1.1-2.5cm',
#   'payer': 'SENIOR WHOLE HEALTH [1014]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 1542.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '34000172',
#   'procedure_description': 'Chg Heart Infarct Image W Ef',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'TUFTS CARELINK PPO [17000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 1750.0,
#   'ip_expected_reimbursement': 1309.0},
#  {'facility_id': 1011999,
#   'procedurename': '105460',
#   'procedure_description': 'HEPARIN, PORCINE (PF) 10 UNIT/ML INTRAVENOUS SYRINGE',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 1.29,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '63600207',
#   'procedure_description': 'Antithrombin (Human) Vl 1iu',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 9.95,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76001235',
#   'procedure_description': 'Renal Ndsc Nephrost W/Ureteral Cath W/WO Dila',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MGB HUMANA [39]',
#   'plan': 'HUMANA PPO POS [101202]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 92% Billed',
#   'ip_price': 6583.0,
#   'ip_expected_reimbursement': 6056.36},
#  {'facility_id': 1011999,
#   'procedurename': '98301006',
#   'procedure_description': 'Arthroscopy Shoulder W/Coracoacrm Ligmnt Release',
#   'payer': "MARTIN'S POINT [160007]",
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]",
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 1692.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30002779',
#   'procedure_description': 'Adamts 13 Antibody',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH HPHC HMO / POS / PPO [329]',
#   'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed',
#   'ip_price': 207.0,
#   'ip_expected_reimbursement': 161.83},
#  {'facility_id': 1011999,
#   'procedurename': '670094',
#   'procedure_description': 'TIBIAL INSERT 13MM SZ 1 SPHERE CR RT 02.12.E0211FR',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 1428.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '25000035',
#   'procedure_description': 'Nitroglycerin Sl Tab 0.3mg (Ea)',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 1.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30002003',
#   'procedure_description': 'Mgh Lysosomal Enzyme Scr',
#   'payer': 'MASSHEALTH [3001]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'MASSHEALTH LIMITED [300105]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 285.0,
#   'ip_expected_reimbursement': 285.0},
#  {'facility_id': 1011999,
#   'procedurename': '98300322',
#   'procedure_description': 'Pf Biopsy Lip',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 278.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '405069',
#   'procedure_description': 'SLING SUBURRETHRAL POLYPROPYLENE MESH IMPLANT DELIVERY DEVICE TRANSVAGINAL ADVANTAGE FIT STRESS URINARY INCONT',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 3786.18,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76001204',
#   'procedure_description': 'Drain Abscess Lymph Node Extensive',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 5145.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '31000058',
#   'procedure_description': 'Protein Analysis W/Band Probe',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]',
#   'plan': 'MGBHP PPO [15000107]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 75.1% Billed',
#   'ip_price': 357.0,
#   'ip_expected_reimbursement': 268.11},
#  {'facility_id': 1011999,
#   'procedurename': '448201',
#   'procedure_description': 'CANNULA NASAL 255CM ADULT CAPNOLINE H O2 MONITORING NASPHION ADAPTER NONINTUBATED DUAL PURPOSE BX/25EA - DISCONTINUED PER MFG',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '27000648',
#   'procedure_description': 'Strattice 128 Sq Cm T3',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA MEDICARE REPLACEMENT [416]',
#   'plan': 'CIGNA PPO MEDICARE REPLACEMENT [100616]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 69% Billed',
#   'ip_price': 8020.0,
#   'ip_expected_reimbursement': 5533.8},
#  {'facility_id': 1011999,
#   'procedurename': '51000090',
#   'procedure_description': 'Medical Team Conf 30 Min Non MD',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MGB HUMANA [39]',
#   'plan': 'HUMANA PPO POS [101202]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 92% Billed',
#   'ip_price': 244.0,
#   'ip_expected_reimbursement': 224.48},
#  {'facility_id': 1011999,
#   'procedurename': '77000016',
#   'procedure_description': 'Preventive Med Counseling 30 Min',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 112.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '520449',
#   'procedure_description': 'KIT CATHETER 5X16MM SINUPLASTY SPINPLUS BALLOON FRONTAL MAX AND SPHEN BX/5EA',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]',
#   'plan': 'BLUE CROSS MA INDEMNITY [11000104]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 3900.0,
#   'ip_expected_reimbursement': 2643.42},
#  {'facility_id': 1011999,
#   'procedurename': '39275',
#   'procedure_description': 'DULOXETINE 20 MG CAPSULE,DELAYED RELEASE',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS PPO [317]',
#   'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 2.14,
#   'ip_expected_reimbursement': 1.45},
#  {'facility_id': 1011999,
#   'procedurename': '32000060',
#   'procedure_description': 'Xr T-Spine 2 Views',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS HMO [316]',
#   'plan': 'BLUE CROSS MA HMO POS [11000103]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 713.0,
#   'ip_expected_reimbursement': 483.27},
#  {'facility_id': 1011999,
#   'procedurename': '123717',
#   'procedure_description': 'CIRCUIT ANESTHESIA PEDIATRIC BREATHING  BXXXXX20 CS/20EA',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]',
#   'plan': 'MGBHP PPO [15000107]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76000699',
#   'procedure_description': 'Appl Splint Forarm/Arm Shrt Static',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 325.0,
#   'ip_expected_reimbursement': 243.1},
#  {'facility_id': 1011999,
#   'procedurename': '32693',
#   'procedure_description': 'SCREW BONE 24.0X4.5MM CORTEX SS STANDARD LG HEXAGONAL SOCKET FLAT HEAD',
#   'payer': 'COMMONWEALTH CARE ALLIANCE [1007]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 149.85,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '31000267',
#   'procedure_description': 'Mgh Dnm2 Dna Sequencing Test',
#   'payer': 'HEALTH NEW ENGLAND [1034]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 4187.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76001989',
#   'procedure_description': 'Splint of Lux/Avuls/Tooth',
#   'payer': 'HEALTH NEW ENGLAND [1034]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 2676.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '75000522',
#   'procedure_description': 'Colonoscopy With Occluder Fistula Closure',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]',
#   'plan': 'BLUE CROSS MA INDEMNITY [11000104]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 15767.0,
#   'ip_expected_reimbursement': 10686.87},
#  {'facility_id': 1011999,
#   'procedurename': '37060',
#   'procedure_description': 'CONTAINER SHARPS 26X12.75 18.25IN BIOHAZARD HINGED LID AUTOCLAVABLE CS/5EA',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS HMO [316]',
#   'plan': 'BLUE CROSS MA HMO POS [11000103]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76000518',
#   'procedure_description': 'Amputate Finger/Thumb W/Flap Local',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 4074.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '98302077',
#   'procedure_description': 'Hallux Rigidus W/Cheilectomy 1st Mp Jt W/O Implt',
#   'payer': 'UNITED HEALTHCARE [1016]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 2294.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30001268',
#   'procedure_description': 'Nucleic Acid Amp Candida',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS PPO [317]',
#   'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 408.0,
#   'ip_expected_reimbursement': 276.54},
#  {'facility_id': 1011999,
#   'procedurename': '27000484',
#   'procedure_description': 'HC Elbow Orthotic Rigid Without Jnt Prefab Tier1',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient PAF; 44.9% Billed',
#   'ip_price': 61.74,
#   'ip_expected_reimbursement': 27.72},
#  {'facility_id': 1011999,
#   'procedurename': '48000146',
#   'procedure_description': 'Perc Transcath Closure Interatrial',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA MEDICARE REPLACEMENT [416]',
#   'plan': 'CIGNA PPO MEDICARE REPLACEMENT [100616]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 69% Billed',
#   'ip_price': 46075.0,
#   'ip_expected_reimbursement': 31791.75},
#  {'facility_id': 1011999,
#   'procedurename': '27000209',
#   'procedure_description': 'HC Stent Non-Coronary Temp With Delivery Tier3',
#   'payer': '<Self-pay>',
#   'contractname': '<Self-pay>',
#   'plan': '<Self-pay>',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': '',
#   'ip_price': 6250.0,
#   'ip_expected_reimbursement': 4687.5},
#  {'facility_id': 1011999,
#   'procedurename': '98300438',
#   'procedure_description': 'Pf Inj Anes Suprascapular Nerve',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MGB HUMANA [39]',
#   'plan': 'HUMANA PPO POS [101202]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 92% Billed',
#   'ip_price': 359.0,
#   'ip_expected_reimbursement': 330.28},
#  {'facility_id': 1011999,
#   'procedurename': '25000059',
#   'procedure_description': 'Naproxen Na Tab 250(275)Mg',
#   'payer': 'MASSHEALTH [3001]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'MASSHEALTH LIMITED [300105]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 54.23,
#   'ip_expected_reimbursement': 54.23},
#  {'facility_id': 1011999,
#   'procedurename': '132781',
#   'procedure_description': 'BLADE HYSTEROSCOPY 4MM TRUCLEAR MORCELLATOR ROTARY',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 1335.0,
#   'ip_expected_reimbursement': 1335.0},
#  {'facility_id': 1011999,
#   'procedurename': '114894',
#   'procedure_description': 'WIRE BONE 1.1 100MM KIRSCHNER SS EXTERNAL FIXATION MARKED ZEBRA BX/6EA - DISCONTINUED PER THE SUPPLIER',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 75.0,
#   'ip_expected_reimbursement': 75.0},
#  {'facility_id': 1011999,
#   'procedurename': '30001978',
#   'procedure_description': 'Mgh Colchr Ms Quan 1 Statnry&Mobl',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 280.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30003424',
#   'procedure_description': 'Mgh Spondylo-Epi-Metaphyseal Dysplasias Ngs Panel',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 51.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '448046',
#   'procedure_description': 'BANDAGE COFLEX 2IN 5YD COMPRESSION SELF ADHERING EASY TEAR ASST COLORS RL/1EA',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]',
#   'plan': 'BLUE CROSS MA INDEMNITY [11000104]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '63601156',
#   'procedure_description': 'Menb-Fhbp Recombnt Lipoprotein Vacc 2/3 Dose Im',
#   'payer': '<Self-pay>',
#   'contractname': '<Self-pay>',
#   'plan': '<Self-pay>',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': '',
#   'ip_price': 299.3,
#   'ip_expected_reimbursement': 224.47},
#  {'facility_id': 1011999,
#   'procedurename': '36000435',
#   'procedure_description': 'Placement Xtn Prosth for Endovascular Rpr',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MGB CIGNA INDEMNITY [32]',
#   'plan': 'CIGNA INDEMNITY [100603]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 8224.0,
#   'ip_expected_reimbursement': 8224.0},
#  {'facility_id': 1011999,
#   'procedurename': '76000169',
#   'procedure_description': 'Graft Full Trunk <20cm',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 7411.0,
#   'ip_expected_reimbursement': 5543.43},
#  {'facility_id': 1011999,
#   'procedurename': '30000073',
#   'procedure_description': 'Blood Processing Autologous',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 727.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '63600168',
#   'procedure_description': 'Metoclopramide Inj 10mg',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 3.83,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '48310',
#   'procedure_description': 'SET CATHETER 6.0MM 7.5CM AIRWAY MELKER EMERGENCY CRICOTHYROTOMY ID G04652',
#   'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 570.03,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '181153',
#   'procedure_description': 'MENINGOCOCCAL B VAC,4-CMP 50 MCG-50 MCG-50 MCG-25 MCG/0.5ML IM SYRINGE',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000001',
# ...
#  {'facility_id': 1011999,
#   'procedurename': '193303',
#   'procedure_description': 'DUPILUMAB 300 MG/2 ML SUBCUTANEOUS SYRINGE',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 5031.53,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '31000869',
#   'procedure_description': 'Certolizumab Level',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 233.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '46000052',
#   'procedure_description': 'Pneumogram Pediatric',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 1332.0,
#   'ip_expected_reimbursement': 996.34},
#  {'facility_id': 1011999,
#   'procedurename': '76000720',
#   'procedure_description': 'Appl Splint Leg Short',
#   'payer': 'SENIOR WHOLE HEALTH [1014]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 162.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76001607',
#   'procedure_description': 'Repair Lac Cornea',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS PPO [317]',
#   'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed',
#   'ip_price': 5735.0,
#   'ip_expected_reimbursement': 3887.18},
#  {'facility_id': 1011999,
#   'procedurename': '424115',
#   'procedure_description': 'SEALER/DIVIDER LIGASURE BLUNT TIP LAPARASCOPIC 5MM BX/6EA - DISCONTINUED PER THE MANUFACTURER USE PS # 532337',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '98300962',
#   'procedure_description': 'Suture Quadriceps/Hamstring Rupture Primary',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; Inpatient PAF; 44.9% Billed',
#   'ip_price': 2248.0,
#   'ip_expected_reimbursement': 1009.35},
#  {'facility_id': 1011999,
#   'procedurename': '130545',
#   'procedure_description': 'PROBE ENDOSCOPY 2.3MM 220MM FIAPC FILTER INTEGRATED ARGON PLASMA COAGULATION CIRCUMFERENTIAL FLEXIBLE CS/10EA',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '121964',
#   'procedure_description': 'HIP COMPONENT 12/14 44MM PLUS 1.5 ARTICULEZE M SPEC METAL OFFSET',
#   'payer': 'HEALTH NEW ENGLAND [1034]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 1200.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '31000749',
#   'procedure_description': 'Sh3bp2 Gene Sequencing',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 532.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '119019',
#   'procedure_description': 'INSULIN LISPRO (U-100) 100 UNIT/ML SUBCUTANEOUS PEN',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'OPPS APC; APC Pricing  (Adjusted APC/APG Price: 0.00), and; Prc Ext - HB XR PRC - MEDICARE OPPS; Note:This line does not qualify for an outlier under OPPS.',
#   'ip_price': 54.18,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30001519',
#   'procedure_description': 'Mgh Tetrahydrocannabinol',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]',
#   'plan': 'BLUE CROSS MA INDEMNITY [11000104]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 287.0,
#   'ip_expected_reimbursement': 194.53},
#  {'facility_id': 1011999,
#   'procedurename': '32893',
#   'procedure_description': 'LEUPROLIDE 7.5 MG (1 MONTH) SUBCUTANEOUS SYRINGE',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'PHR: 4080000631; CHG: 408000007',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 282.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '27000583',
#   'procedure_description': 'Hm Holster Vest or Battery Holster',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA MEDICARE REPLACEMENT [416]',
#   'plan': 'CIGNA PPO MEDICARE REPLACEMENT [100616]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 69% Billed',
#   'ip_price': 1382.5,
#   'ip_expected_reimbursement': 953.93},
#  {'facility_id': 1011999,
#   'procedurename': '76000284',
#   'procedure_description': 'Rem FB Muscle/Tendon Cplx',
#   'payer': 'HUMANA [1012]',
#   'contractname': 'HB MGB HUMANA [39]',
#   'plan': 'HUMANA PPO POS [101202]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 92% Billed',
#   'ip_price': 5489.0,
#   'ip_expected_reimbursement': 5049.88},
#  {'facility_id': 1011999,
#   'procedurename': '62400050',
#   'procedure_description': 'Mgh P001608 Nir Cath Infraredx',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'MGBHP CONNECTORCARE NON MGB PCP [15000106]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 1.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30003280',
#   'procedure_description': 'Hiv Antigen/Antibody, Combination Assay, Screening',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MGB CIGNA INDEMNITY [32]',
#   'plan': 'CIGNA INDEMNITY [100603]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 294.0,
#   'ip_expected_reimbursement': 294.0},
#  {'facility_id': 1011999,
#   'procedurename': '358909',
#   'procedure_description': 'PLATE WIRE 30MM 3 HOLE WRIST FIXATION SYSTEM',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'CIGNA CARELINK PPO [100601]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed',
#   'ip_price': 1290.0,
#   'ip_expected_reimbursement': 982.98},
#  {'facility_id': 1011999,
#   'procedurename': '98300339',
#   'procedure_description': 'Pf Sigmoidoscopy Flex',
#   'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 600.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '31000605',
#   'procedure_description': 'Mgh X?Adrenoleukodystrophy Abcd1 Mlpa',
#   'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]',
#   'contractname': 'HB MVH MEDICAID [254]',
#   'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 894.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '75000516',
#   'procedure_description': 'GI Tract Imaging Intraluminal Colon I&R',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]',
#   'plan': 'MGBHP PPO [15000107]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 75.1% Billed',
#   'ip_price': 4662.0,
#   'ip_expected_reimbursement': 3501.16},
#  {'facility_id': 1011999,
#   'procedurename': '31000897',
#   'procedure_description': 'F9 Full Gene Sequence',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'BLUE CROSS MA MEDICARE HMO BLUE REPLACEMENT [11000107]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 6846.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '414833',
#   'procedure_description': 'HIP STEM 12 TO 14 145MM SIZE 11 FEMORAL SYNERGY TITANIUM POROUS COATED HIGH OFFSET TAPER',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 3600.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30001984',
#   'procedure_description': 'Mgh Duloxetine Serum',
#   'payer': 'CIGNA [1006]',
#   'contractname': 'HB MVH CIGNA HMO / PPO [273]',
#   'plan': 'CIGNA HMO POS [100602]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed',
#   'ip_price': 280.0,
#   'ip_expected_reimbursement': 255.92},
#  {'facility_id': 1011999,
#   'procedurename': '307480',
#   'procedure_description': 'BIT DRILL 175X2.5MM BONE CANNULATED ANKLE FRACTURE MGMT SYSTEM',
#   'payer': 'COMMONWEALTH CARE ALLIANCE [1007]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '304195',
#   'procedure_description': 'BLADE ARTHROSCOPY 3.5MM 7CM DYONICS POWER MINI STAINLESS STEEL INCISOR PLUS ELITE DISPOSABLE SAGE GREEN BX/6EA',
#   'payer': 'WELLSENSE [1003]',
#   'contractname': 'HB MVH WELLSENSE MCO [333]',
#   'plan': 'WELLSENSE MASSHEALTH MCO [100302]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '505529',
#   'procedure_description': 'KNEE INSERT 12MM SZ 7 8 JOURNEY II BCS CROSSLINKED POLYETHYLENE RIGHT',
#   'payer': 'SENIOR WHOLE HEALTH [1014]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 1428.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '30002749',
#   'procedure_description': 'Mgh Osmolality, Potassium',
#   'payer': 'HARVARD PILGRIM [120001]',
#   'contractname': 'HB MVH HPHC HMO / POS / PPO [329]',
#   'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed',
#   'ip_price': 74.0,
#   'ip_expected_reimbursement': 57.85},
#  {'facility_id': 1011999,
#   'procedurename': '31000307',
#   'procedure_description': 'Mgh Compar Genom Hybrd 180000 Prob',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'TUFTS CARELINK PPO [17000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 3609.0,
#   'ip_expected_reimbursement': 2699.53},
#  {'facility_id': 1011999,
#   'procedurename': '34000065',
#   'procedure_description': 'NM Pulmonary Perfusion Imaging',
#   'payer': 'TUFTS HEALTH PLAN [170001]',
#   'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]',
#   'plan': 'TUFTS CARELINK PPO [17000101]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient HMO PAF; 74.8% Billed',
#   'ip_price': 1515.0,
#   'ip_expected_reimbursement': 1133.22},
#  {'facility_id': 1011999,
#   'procedurename': '30002245',
#   'procedure_description': 'Mgh Antb Virus Nes',
#   'payer': 'AETNA [1001]',
#   'contractname': 'HB MGB AETNA INDEMNITY [31]',
#   'plan': 'AETNA INDEMNITY [100102]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed',
#   'ip_price': 148.0,
#   'ip_expected_reimbursement': 148.0},
#  {'facility_id': 1011999,
#   'procedurename': '30003557',
#   'procedure_description': 'Streptococcus Pneumoniae Igg Antibodies, 23 Serotypes, Serum',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS HMO [316]',
#   'plan': 'BLUE CROSS MA HMO POS [11000103]',
#   'ip_pricing_detail': 'FSC: 48; Median of: 1',
#   'ip_xr_detail': 'Inpatient PAF; 67.78% Billed',
#   'ip_price': 234.0,
#   'ip_expected_reimbursement': 158.61},
#  {'facility_id': 1011999,
#   'procedurename': '32708',
#   'procedure_description': 'BIT DRILL 100X3.5MM BONE SS QUICK COUPLING',
#   'payer': 'BLUE CROSS BLUE SHIELD [110001]',
#   'contractname': 'HB MVH BLUE CROSS PPO [317]',
#   'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No historical claim',
#   'ip_price': 0.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '76000239',
#   'procedure_description': 'Chemosurg/Mohs Ea Add Spec >5',
#   'payer': 'MGB HEALTH PLAN [150001]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]',
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 233.0,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '180463',
#   'procedure_description': 'SCREW BONE 3.5X45MM CORTEX SS SELF TAPPING T15 STARDRIVE RECESS',
#   'payer': 'COMMONWEALTH CARE ALLIANCE [1007]',
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]',
#   'ip_pricing_detail': 'Inv Loc: 3061000003; from OR location 3061000003',
#   'ip_xr_detail': 'No contract line matched',
#   'ip_price': 72.15,
#   'ip_expected_reimbursement': 0.0},
#  {'facility_id': 1011999,
#   'procedurename': '39000018',
#   'procedure_description': 'Red Cells Irradiated Ea',
#   'payer': "MARTIN'S POINT [160007]",
#   'contractname': 'HB MVH MEDICARE [434]',
#   'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]",
#   'ip_pricing_detail': 'FSC: 296; BFG: 52',
#   'ip_xr_detail': 'No historical claim; No contract line matched',
#   'ip_price': 634.0,
#   'ip_expected_reimbursement': 0.0},
#  ...]

# %%
# Create Embeddings (Vectorize) and Upsert to Qdrant
batch_size=200
vector_limit=10000000

json_list = json_list[:vector_limit]

for i in tqdm(range(0, len(json_list), batch_size)):
    # find end of batch
    i_end = min(i+batch_size, len(json_list))
    
    qdrant.upsert(
        collection_name="HospitalCharges",
        points=[
            models.PointStruct(
                id=idx+i_end, #ID for the record in the collection
                vector=encoderModel.encode(doc["procedure_description"]).tolist(), #encoded vector text
                payload=doc #meta data for the records
            ) for idx, doc in enumerate(json_list[i:i_end])
            ]
        )
# Out:
#   0%|          | 0/2223 [00:00<?, ?it/s]

# %%
# Let's now search for something
query = 'Appendicectomy procedure'

hits = qdrant.search(
    collection_name="HospitalCharges",
    query_vector=encoderModel.encode(query).tolist(),
    limit=30
)
for hit in hits:
  print(hit.payload, "score:", hit.score)
# Out:
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 2036.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]', 'procedure_description': 'Laparoscopic Appendectomy', 'procedurename': '98301068'} score: 0.75502884
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 2036.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Laparoscopic Appendectomy', 'procedurename': '98301068'} score: 0.75502884
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 509.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'Escharotomy Ea Add Incision', 'procedurename': '76000209'} score: 0.5429762
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 509.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Escharotomy Ea Add Incision', 'procedurename': '76000209'} score: 0.5429762
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 34698.22, 'ip_price': 46388.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient HMO PAF; 74.8% Billed', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS CARELINK PPO [17000101]', 'procedure_description': 'Excision Infected Graft Abdomen', 'procedurename': '36000163'} score: 0.52705413
# {'contractname': 'HB MVH BLUE CROSS HMO [316]', 'facility_id': 1011999, 'ip_expected_reimbursement': 31441.79, 'ip_price': 46388.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA HMO POS [11000103]', 'procedure_description': 'Excision Infected Graft Abdomen', 'procedurename': '36000163'} score: 0.52705413
# {'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]', 'facility_id': 1011999, 'ip_expected_reimbursement': 34837.39, 'ip_price': 46388.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 75.1% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP PPO [15000107]', 'procedure_description': 'Excision Infected Graft Abdomen', 'procedurename': '36000163'} score: 0.52705413
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 46388.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'SENIOR WHOLE HEALTH [1014]', 'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]', 'procedure_description': 'Excision Infected Graft Abdomen', 'procedurename': '36000163'} score: 0.52705413
# {'contractname': 'HB MGB AETNA INDEMNITY [31]', 'facility_id': 1011999, 'ip_expected_reimbursement': 46388.0, 'ip_price': 46388.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA INDEMNITY [100102]', 'procedure_description': 'Excision Infected Graft Abdomen', 'procedurename': '36000163'} score: 0.52705413
# {'contractname': 'HB MVH AETNA [330]', 'facility_id': 1011999, 'ip_expected_reimbursement': 38965.92, 'ip_price': 46388.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient PAF; 84% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA HMO POS EPO [100101]', 'procedure_description': 'Excision Infected Graft Abdomen', 'procedurename': '36000163'} score: 0.52705413
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 2896.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'AETNA [1001]', 'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]', 'procedure_description': 'Dest Lesion Anus Surgical Excision', 'procedurename': '75000235'} score: 0.5008433
# {'contractname': 'HB MVH BLUE CROSS HMO [316]', 'facility_id': 1011999, 'ip_expected_reimbursement': 1962.91, 'ip_price': 2896.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA HMO POS [11000103]', 'procedure_description': 'Dest Lesion Anus Surgical Excision', 'procedurename': '75000235'} score: 0.5008433
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 2896.0, 'ip_price': 2896.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'Dest Lesion Anus Surgical Excision', 'procedurename': '75000235'} score: 0.5008433
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 2896.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Dest Lesion Anus Surgical Excision', 'procedurename': '75000235'} score: 0.5008433
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 2896.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]', 'procedure_description': 'Dest Lesion Anus Surgical Excision', 'procedurename': '75000235'} score: 0.5008433
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA MEDICARE HMO BLUE REPLACEMENT [11000107]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 4475.9, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'SENIOR WHOLE HEALTH [1014]', 'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]', 'facility_id': 1011999, 'ip_expected_reimbursement': 4243.03, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA INDEMNITY [11000104]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': '<Self-pay>', 'facility_id': 1011999, 'ip_expected_reimbursement': 4695.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': '', 'payer': '<Self-pay>', 'plan': '<Self-pay>', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 6260.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'MASSHEALTH [3001]', 'plan': 'MASSHEALTH LIMITED [300105]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': "MARTIN'S POINT [160007]", 'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]", 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 6260.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'AETNA [1001]', 'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH BLUE CROSS PPO [317]', 'facility_id': 1011999, 'ip_expected_reimbursement': 4243.03, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MGB AETNA INDEMNITY [31]', 'facility_id': 1011999, 'ip_expected_reimbursement': 6260.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA INDEMNITY [100102]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH CIGNA HMO / PPO [273]', 'facility_id': 1011999, 'ip_expected_reimbursement': 5721.64, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; Inpatient / Outpatient PAF; 91.4% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA HMO POS [100602]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 6260.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No historical claim; No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'Hemorrhoidectomy External 2 or More', 'procedurename': '75000217'} score: 0.47875553

# %%
dfResults = pd.DataFrame([hit.payload for hit in hits])

# %%
dfResults
# Out:
#                                contractname  facility_id  \
# 0                     HB MVH MEDICARE [434]      1011999
# 1                     HB MVH MEDICAID [254]      1011999
# 2                     HB MVH MEDICARE [434]      1011999
# 3                     HB MVH MEDICAID [254]      1011999
# 4   HB MVH TUFTS HMO / PPO / CARELINK [327]      1011999
# 5               HB MVH BLUE CROSS HMO [316]      1011999
# 6         HB MVH MGBHP COMMERCIAL PPO [417]      1011999
# 7                     HB MVH MEDICARE [434]      1011999
# 8               HB MGB AETNA INDEMNITY [31]      1011999
# 9                        HB MVH AETNA [330]      1011999
# 10                    HB MVH MEDICARE [434]      1011999
# 11              HB MVH BLUE CROSS HMO [316]      1011999
# 12              HB MGB CIGNA INDEMNITY [32]      1011999
# 13                    HB MVH MEDICAID [254]      1011999
# 14                    HB MVH MEDICARE [434]      1011999
# 15                    HB MVH MEDICARE [434]      1011999
# 16                    HB MVH MEDICAID [254]      1011999
# 17        HB MVH MGBHP COMMERCIAL HMO [267]      1011999
# 18                    HB MVH MEDICARE [434]      1011999
# 19        HB MVH BLUE CROSS INDEMNITY [318]      1011999
# 20                               <Self-pay>      1011999
# 21                    HB MVH MEDICAID [254]      1011999
# 22                    HB MVH MEDICARE [434]      1011999
# 23              HB MGB CIGNA INDEMNITY [32]      1011999
# 24                    HB MVH MEDICARE [434]      1011999
# 25              HB MVH BLUE CROSS PPO [317]      1011999
# 26              HB MGB AETNA INDEMNITY [31]      1011999
# 27                    HB MVH MEDICAID [254]      1011999
# 28             HB MVH CIGNA HMO / PPO [273]      1011999
# 29                    HB MVH MEDICARE [434]      1011999
#
#     ip_expected_reimbursement  ip_price      ip_pricing_detail  \
# 0                        0.00    2036.0      FSC: 296; BFG: 52
# 1                        0.00    2036.0      FSC: 296; BFG: 52
# 2                        0.00     509.0  FSC: 48; Median of: 1
# 3                        0.00     509.0  FSC: 48; Median of: 1
# 4                    34698.22   46388.0  FSC: 48; Median of: 1
# 5                    31441.79   46388.0  FSC: 48; Median of: 1
# 6                    34837.39   46388.0  FSC: 48; Median of: 1
# 7                        0.00   46388.0  FSC: 48; Median of: 1
# 8                    46388.00   46388.0  FSC: 48; Median of: 1
# 9                    38965.92   46388.0  FSC: 48; Median of: 1
# 10                       0.00    2896.0      FSC: 296; BFG: 52
# 11                    1962.91    2896.0      FSC: 296; BFG: 52
# 12                    2896.00    2896.0      FSC: 296; BFG: 52
# 13                       0.00    2896.0      FSC: 296; BFG: 52
# 14                       0.00    2896.0      FSC: 296; BFG: 52
# 15                       0.00    6260.0  FSC: 48; Median of: 1
# 16                       0.00    6260.0  FSC: 48; Median of: 1
# 17                    4475.90    6260.0  FSC: 48; Median of: 1
# 18                       0.00    6260.0  FSC: 48; Median of: 1
# 19                    4243.03    6260.0  FSC: 48; Median of: 1
# 20                    4695.00    6260.0  FSC: 48; Median of: 1
# 21                    6260.00    6260.0  FSC: 48; Median of: 1
# 22                       0.00    6260.0  FSC: 48; Median of: 1
# 23                    6260.00    6260.0  FSC: 48; Median of: 1
# 24                       0.00    6260.0  FSC: 48; Median of: 1
# 25                    4243.03    6260.0  FSC: 48; Median of: 1
# 26                    6260.00    6260.0  FSC: 48; Median of: 1
# 27                       0.00    6260.0  FSC: 48; Median of: 1
# 28                    5721.64    6260.0  FSC: 48; Median of: 1
# 29                       0.00    6260.0  FSC: 48; Median of: 1
#
#                                          ip_xr_detail  \
# 0                            No contract line matched
# 1                            No contract line matched
# 2       No historical claim; No contract line matched
# 3       No historical claim; No contract line matched
# 4   No historical claim; Inpatient / Outpatient HM...
# 5   No historical claim; Inpatient PAF; 67.78% Billed
# 6   No historical claim; Inpatient / Outpatient PA...
# 7       No historical claim; No contract line matched
# 8   No historical claim; Inpatient / Outpatient In...
# 9      No historical claim; Inpatient PAF; 84% Billed
# 10      No historical claim; No contract line matched
# 11  No historical claim; Inpatient PAF; 67.78% Billed
# 12  No historical claim; Inpatient / Outpatient In...
# 13      No historical claim; No contract line matched
# 14      No historical claim; No contract line matched
# 15      No historical claim; No contract line matched
# 16      No historical claim; No contract line matched
# 17  No historical claim; Inpatient / Outpatient PA...
# 18      No historical claim; No contract line matched
# 19  No historical claim; Inpatient PAF; 67.78% Billed
# 20
# 21      No historical claim; No contract line matched
# 22      No historical claim; No contract line matched
# 23  No historical claim; Inpatient / Outpatient In...
# 24      No historical claim; No contract line matched
# 25  No historical claim; Inpatient PAF; 67.78% Billed
# 26  No historical claim; Inpatient / Outpatient In...
# 27      No historical claim; No contract line matched
# 28  No historical claim; Inpatient / Outpatient PA...
# 29      No historical claim; No contract line matched
#
#                                payer  \
# 0           UNITED HEALTHCARE [1016]
# 1          HEALTH NEW ENGLAND [1034]
# 2         TUFTS HEALTH PLAN [170001]
# 3          HEALTH NEW ENGLAND [1034]
# 4         TUFTS HEALTH PLAN [170001]
# 5    BLUE CROSS BLUE SHIELD [110001]
# 6           MGB HEALTH PLAN [150001]
# 7         SENIOR WHOLE HEALTH [1014]
# 8                       AETNA [1001]
# 9                       AETNA [1001]
# 10                      AETNA [1001]
# 11   BLUE CROSS BLUE SHIELD [110001]
# 12                      CIGNA [1006]
# 13         HEALTH NEW ENGLAND [1034]
# 14          UNITED HEALTHCARE [1016]
# 15   BLUE CROSS BLUE SHIELD [110001]
# 16  TUFTS HEALTH PUBLIC PLANS [1013]
# 17          MGB HEALTH PLAN [150001]
# 18        SENIOR WHOLE HEALTH [1014]
# 19   BLUE CROSS BLUE SHIELD [110001]
# 20                        <Self-pay>
# 21                 MASSHEALTH [3001]
# 22           MARTIN'S POINT [160007]
# 23                      CIGNA [1006]
# 24                      AETNA [1001]
# 25   BLUE CROSS BLUE SHIELD [110001]
# 26                      AETNA [1001]
# 27         HEALTH NEW ENGLAND [1034]
# 28                      CIGNA [1006]
# 29        TUFTS HEALTH PLAN [170001]
#
#                                                  plan  \
# 0   UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACE...
# 1          HEALTH NEW ENGLAND CONNECTOR CARE [103102]
# 2   TUFTS MEDICARE PREFERRED HMO REPLACEMENT [1700...
# 3          HEALTH NEW ENGLAND CONNECTOR CARE [103102]
# 4                       TUFTS CARELINK PPO [17000101]
# 5                    BLUE CROSS MA HMO POS [11000103]
# 6                                MGBHP PPO [15000107]
# 7   SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]
# 8                            AETNA INDEMNITY [100102]
# 9                          AETNA HMO POS EPO [100101]
# 10            AETNA PPO MEDICARE REPLACEMENT [100103]
# 11                   BLUE CROSS MA HMO POS [11000103]
# 12                           CIGNA INDEMNITY [100603]
# 13         HEALTH NEW ENGLAND CONNECTOR CARE [103102]
# 14  UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACE...
# 15  BLUE CROSS MA MEDICARE HMO BLUE REPLACEMENT [1...
# 16  TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [10...
# 17                               MGBHP HMO [15000102]
# 18  SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]
# 19                 BLUE CROSS MA INDEMNITY [11000104]
# 20                                         <Self-pay>
# 21                        MASSHEALTH LIMITED [300105]
# 22  MARTIN'S POINT GENERATIONS ADV HMO MEDICARE RE...
# 23                           CIGNA INDEMNITY [100603]
# 24            AETNA PPO MEDICARE REPLACEMENT [100103]
# 25  BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000...
# 26                           AETNA INDEMNITY [100102]
# 27         HEALTH NEW ENGLAND CONNECTOR CARE [103102]
# 28                             CIGNA HMO POS [100602]
# 29  TUFTS MEDICARE PREFERRED HMO REPLACEMENT [1700...
#
#                   procedure_description procedurename
# 0             Laparoscopic Appendectomy      98301068
# 1             Laparoscopic Appendectomy      98301068
# 2           Escharotomy Ea Add Incision      76000209
# 3           Escharotomy Ea Add Incision      76000209
# 4       Excision Infected Graft Abdomen      36000163
# 5       Excision Infected Graft Abdomen      36000163
# 6       Excision Infected Graft Abdomen      36000163
# 7       Excision Infected Graft Abdomen      36000163
# 8       Excision Infected Graft Abdomen      36000163
# 9       Excision Infected Graft Abdomen      36000163
# 10   Dest Lesion Anus Surgical Excision      75000235
# 11   Dest Lesion Anus Surgical Excision      75000235
# 12   Dest Lesion Anus Surgical Excision      75000235
# 13   Dest Lesion Anus Surgical Excision      75000235
# 14   Dest Lesion Anus Surgical Excision      75000235
# 15  Hemorrhoidectomy External 2 or More      75000217
# 16  Hemorrhoidectomy External 2 or More      75000217
# 17  Hemorrhoidectomy External 2 or More      75000217
# 18  Hemorrhoidectomy External 2 or More      75000217
# 19  Hemorrhoidectomy External 2 or More      75000217
# 20  Hemorrhoidectomy External 2 or More      75000217
# 21  Hemorrhoidectomy External 2 or More      75000217
# 22  Hemorrhoidectomy External 2 or More      75000217
# 23  Hemorrhoidectomy External 2 or More      75000217
# 24  Hemorrhoidectomy External 2 or More      75000217
# 25  Hemorrhoidectomy External 2 or More      75000217
# 26  Hemorrhoidectomy External 2 or More      75000217
# 27  Hemorrhoidectomy External 2 or More      75000217
# 28  Hemorrhoidectomy External 2 or More      75000217
# 29  Hemorrhoidectomy External 2 or More      75000217

# %%
query="Admin of Flumist Influenza Vaccine"
hits = qdrant.search(
    collection_name="HospitalCharges",
    query_vector=encoderModel.encode(query).tolist(),
    limit=300
)
for hit in hits:
  print(hit.payload, "score:", hit.score)
# Out:
# {'contractname': 'HB MVH HPHC HMO / POS / PPO [329]', 'facility_id': 1011999, 'ip_expected_reimbursement': 22.67, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'AETNA [1001]', 'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': "MARTIN'S POINT [160007]", 'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]", 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MGB AETNA INDEMNITY [31]', 'facility_id': 1011999, 'ip_expected_reimbursement': 30.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA INDEMNITY [100102]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH BLUE CROSS HMO [316]', 'facility_id': 1011999, 'ip_expected_reimbursement': 19.66, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA HMO POS [11000103]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH WELLSENSE MCO [333]', 'facility_id': 1011999, 'ip_expected_reimbursement': 13.02, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient PAF; 44.9% Billed', 'payer': 'WELLSENSE [1003]', 'plan': 'WELLSENSE MASSHEALTH MCO [100302]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'COMMONWEALTH CARE ALLIANCE [1007]', 'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 29.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]', 'facility_id': 1011999, 'ip_expected_reimbursement': 20.33, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA INDEMNITY [11000104]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': "MARTIN'S POINT [160007]", 'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]", 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MGB HUMANA [39]', 'facility_id': 1011999, 'ip_expected_reimbursement': 26.68, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 92% Billed', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA PPO POS [101202]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA MEDICARE HMO BLUE REPLACEMENT [11000107]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 22.44, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient HMO PAF; 74.8% Billed', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS CARELINK PPO [17000101]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MGB AETNA INDEMNITY [31]', 'facility_id': 1011999, 'ip_expected_reimbursement': 29.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA INDEMNITY [100102]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]', 'facility_id': 1011999, 'ip_expected_reimbursement': 21.78, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 75.1% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP PPO [15000107]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'COMMONWEALTH CARE ALLIANCE [1007]', 'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]', 'facility_id': 1011999, 'ip_expected_reimbursement': 27.12, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': '<Self-pay>', 'facility_id': 1011999, 'ip_expected_reimbursement': 22.5, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': '', 'payer': '<Self-pay>', 'plan': '<Self-pay>', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH HPHC HMO / POS / PPO [329]', 'facility_id': 1011999, 'ip_expected_reimbursement': 23.45, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH PHCS [332]', 'facility_id': 1011999, 'ip_expected_reimbursement': 26.39, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient PAF; 91% Billed', 'payer': 'PHCS MULTIPLAN [1022]', 'plan': 'GENERIC PHCS MULTIPLAN [102201]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'SENIOR WHOLE HEALTH [1014]', 'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH AETNA [330]', 'facility_id': 1011999, 'ip_expected_reimbursement': 25.2, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient PAF; 84% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA HMO POS EPO [100101]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 30.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'MASSHEALTH [3001]', 'plan': 'MASSHEALTH LIMITED [300105]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH BLUE CROSS PPO [317]', 'facility_id': 1011999, 'ip_expected_reimbursement': 20.33, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 22.44, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient HMO PAF; 74.8% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA CARELINK PPO [100601]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH CIGNA HMO / PPO [273]', 'facility_id': 1011999, 'ip_expected_reimbursement': 26.51, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA HMO POS [100602]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 20.74, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 21.45, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH AETNA [330]', 'facility_id': 1011999, 'ip_expected_reimbursement': 24.36, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient PAF; 84% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA HMO POS EPO [100101]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100008'} score: 0.917377
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'Admin of Influenza Vaccine', 'procedurename': '77100007'} score: 0.917377
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 166.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MASSHEALTH [3001]', 'plan': 'MASSHEALTH LIMITED [300105]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH CIGNA MEDICARE REPLACEMENT [416]', 'facility_id': 1011999, 'ip_expected_reimbursement': 114.54, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 69% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA PPO MEDICARE REPLACEMENT [100616]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'SENIOR WHOLE HEALTH [1014]', 'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 126.49, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA CARELINK PPO [100601]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 118.69, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH AETNA [330]', 'facility_id': 1011999, 'ip_expected_reimbursement': 139.44, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 84% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA HMO POS EPO [100101]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]', 'facility_id': 1011999, 'ip_expected_reimbursement': 112.51, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA INDEMNITY [11000104]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': '<Self-pay>', 'facility_id': 1011999, 'ip_expected_reimbursement': 124.5, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': '', 'payer': '<Self-pay>', 'plan': '<Self-pay>', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MGB HUMANA [39]', 'facility_id': 1011999, 'ip_expected_reimbursement': 152.72, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 92% Billed', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA PPO POS [101202]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH PHCS [332]', 'facility_id': 1011999, 'ip_expected_reimbursement': 151.06, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 91% Billed', 'payer': 'PHCS MULTIPLAN [1022]', 'plan': 'GENERIC PHCS MULTIPLAN [102201]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]', 'facility_id': 1011999, 'ip_expected_reimbursement': 124.67, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 75.1% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP PPO [15000107]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH HPHC HMO / POS / PPO [329]', 'facility_id': 1011999, 'ip_expected_reimbursement': 129.78, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': "MARTIN'S POINT [160007]", 'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]", 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA MEDICARE HMO BLUE REPLACEMENT [11000107]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]', 'facility_id': 1011999, 'ip_expected_reimbursement': 150.05, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH BLUE CROSS HMO [316]', 'facility_id': 1011999, 'ip_expected_reimbursement': 112.51, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA HMO POS [11000103]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'COMMONWEALTH CARE ALLIANCE [1007]', 'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MGB AETNA INDEMNITY [31]', 'facility_id': 1011999, 'ip_expected_reimbursement': 166.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA INDEMNITY [100102]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 166.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'AETNA [1001]', 'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 126.49, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS CARELINK PPO [17000101]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH WELLSENSE MCO [333]', 'facility_id': 1011999, 'ip_expected_reimbursement': 74.53, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 44.9% Billed', 'payer': 'WELLSENSE [1003]', 'plan': 'WELLSENSE MASSHEALTH MCO [100302]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP CONNECTORCARE NON MGB PCP [15000106]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH BLUE CROSS PPO [317]', 'facility_id': 1011999, 'ip_expected_reimbursement': 112.51, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH CIGNA HMO / PPO [273]', 'facility_id': 1011999, 'ip_expected_reimbursement': 151.72, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA HMO POS [100602]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 166.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]', 'procedure_description': 'Influenza Antibody', 'procedurename': '30000961'} score: 0.6084579
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'Admin of Pneumococcal Vaccine', 'procedurename': '77100009'} score: 0.5566968
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]', 'procedure_description': 'Admin of Pneumococcal Vaccine', 'procedurename': '77100010'} score: 0.5566968
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]', 'procedure_description': 'Admin of Pneumococcal Vaccine', 'procedurename': '77100009'} score: 0.5566968
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 29.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'MASSHEALTH [3001]', 'plan': 'MASSHEALTH LIMITED [300105]', 'procedure_description': 'Admin of Pneumococcal Vaccine', 'procedurename': '77100010'} score: 0.5566968
# {'contractname': 'HB MGB HUMANA [39]', 'facility_id': 1011999, 'ip_expected_reimbursement': 168.36, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 92% Billed', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA PPO POS [101202]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH AETNA [330]', 'facility_id': 1011999, 'ip_expected_reimbursement': 153.72, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 84% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA HMO POS EPO [100101]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 183.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP CONNECTORCARE NON MGB PCP [15000106]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH WELLSENSE MCO [333]', 'facility_id': 1011999, 'ip_expected_reimbursement': 82.17, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 44.9% Billed', 'payer': 'WELLSENSE [1003]', 'plan': 'WELLSENSE MASSHEALTH MCO [100302]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA MEDICARE HMO BLUE REPLACEMENT [11000107]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH BLUE CROSS PPO [317]', 'facility_id': 1011999, 'ip_expected_reimbursement': 124.04, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]', 'facility_id': 1011999, 'ip_expected_reimbursement': 137.43, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 75.1% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP PPO [15000107]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': "MARTIN'S POINT [160007]", 'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]", 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 130.85, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MGB AETNA INDEMNITY [31]', 'facility_id': 1011999, 'ip_expected_reimbursement': 183.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA INDEMNITY [100102]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH PHCS [332]', 'facility_id': 1011999, 'ip_expected_reimbursement': 166.53, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 91% Billed', 'payer': 'PHCS MULTIPLAN [1022]', 'plan': 'GENERIC PHCS MULTIPLAN [102201]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'AETNA [1001]', 'plan': 'AETNA PPO MEDICARE REPLACEMENT [100103]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 139.45, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA CARELINK PPO [100601]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 139.45, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS CARELINK PPO [17000101]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]', 'facility_id': 1011999, 'ip_expected_reimbursement': 165.41, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]', 'facility_id': 1011999, 'ip_expected_reimbursement': 124.04, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA INDEMNITY [11000104]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH BLUE CROSS HMO [316]', 'facility_id': 1011999, 'ip_expected_reimbursement': 124.04, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA HMO POS [11000103]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH HPHC HMO / POS / PPO [329]', 'facility_id': 1011999, 'ip_expected_reimbursement': 143.07, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH CIGNA MEDICARE REPLACEMENT [416]', 'facility_id': 1011999, 'ip_expected_reimbursement': 126.27, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 69% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA PPO MEDICARE REPLACEMENT [100616]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': '<Self-pay>', 'facility_id': 1011999, 'ip_expected_reimbursement': 137.25, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': '', 'payer': '<Self-pay>', 'plan': '<Self-pay>', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 183.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MASSHEALTH [3001]', 'plan': 'MASSHEALTH LIMITED [300105]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'SENIOR WHOLE HEALTH [1014]', 'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH CIGNA HMO / PPO [273]', 'facility_id': 1011999, 'ip_expected_reimbursement': 167.26, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA HMO POS [100602]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'COMMONWEALTH CARE ALLIANCE [1007]', 'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]', 'procedure_description': 'If Influenza a Antigen', 'procedurename': '30001216'} score: 0.5402145
# {'contractname': 'HB MVH BLUE CROSS PPO [317]', 'facility_id': 1011999, 'ip_expected_reimbursement': 124.04, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'COMMONWEALTH CARE ALLIANCE [1007]', 'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 183.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 183.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MASSHEALTH [3001]', 'plan': 'MASSHEALTH LIMITED [300105]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH AETNA [330]', 'facility_id': 1011999, 'ip_expected_reimbursement': 153.72, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 84% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA HMO POS EPO [100101]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': '<Self-pay>', 'facility_id': 1011999, 'ip_expected_reimbursement': 137.25, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': '', 'payer': '<Self-pay>', 'plan': '<Self-pay>', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH BLUE CROSS HMO [316]', 'facility_id': 1011999, 'ip_expected_reimbursement': 124.04, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA HMO POS [11000103]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH HPHC HMO / POS / PPO [329]', 'facility_id': 1011999, 'ip_expected_reimbursement': 143.07, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MGB AETNA INDEMNITY [31]', 'facility_id': 1011999, 'ip_expected_reimbursement': 183.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'AETNA [1001]', 'plan': 'AETNA INDEMNITY [100102]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH CIGNA MEDICARE REPLACEMENT [416]', 'facility_id': 1011999, 'ip_expected_reimbursement': 126.27, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 69% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA PPO MEDICARE REPLACEMENT [100616]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP CONNECTORCARE NON MGB PCP [15000106]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 130.85, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# {'contractname': 'HB MVH PHCS [332]', 'facility_id': 1011999, 'ip_expected_reimbursement': 166.53, 'ip_price': 183.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 91% Billed', 'payer': 'PHCS MULTIPLAN [1022]', 'plan': 'GENERIC PHCS MULTIPLAN [102201]', 'procedure_description': 'If Influenza B Antigen', 'procedurename': '30001215'} score: 0.52079076
# ...
# {'contractname': 'HB MGB HUMANA [39]', 'facility_id': 1011999, 'ip_expected_reimbursement': 119.6, 'ip_price': 130.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 92% Billed', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA PPO POS [101202]', 'procedure_description': 'Haemophilus Influenza Antibody', 'procedurename': '30000938'} score: 0.48219374
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 130.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]', 'procedure_description': 'Haemophilus Influenza Antibody', 'procedurename': '30000938'} score: 0.48219374
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 130.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'Haemophilus Influenza Antibody', 'procedurename': '30000938'} score: 0.48219374
# {'contractname': 'HB MVH CIGNA HMO / PPO [273]', 'facility_id': 1011999, 'ip_expected_reimbursement': 118.82, 'ip_price': 130.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA HMO POS [100602]', 'procedure_description': 'Haemophilus Influenza Antibody', 'procedurename': '30000938'} score: 0.48219374
# {'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]', 'facility_id': 1011999, 'ip_expected_reimbursement': 27.12, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]', 'procedure_description': 'Admin Hepatitis B Vaccine No Fee', 'procedurename': '77100011'} score: 0.47839352
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]', 'procedure_description': 'Admin Hepatitis B Vaccine No Fee', 'procedurename': '77100012'} score: 0.47839352
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 21.45, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'Admin Hepatitis B Vaccine No Fee', 'procedurename': '77100011'} score: 0.47839352
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 29.0, 'ip_price': 29.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'Admin Hepatitis B Vaccine No Fee', 'procedurename': '77100012'} score: 0.47839352
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'Admin Hepatitis B Vaccine No Fee', 'procedurename': '77100011'} score: 0.47839352
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 30.0, 'ip_pricing_detail': 'FSC: 296; BFG: 52', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'Admin Hepatitis B Vaccine No Fee', 'procedurename': '77100011'} score: 0.47839352
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS MEDICARE PREFERRED HMO REPLACEMENT [17000103]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH BLUE CROSS PPO [317]', 'facility_id': 1011999, 'ip_expected_reimbursement': 608.66, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS BLUE BENEFITS ADMINISTRATORS [11000101]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HEALTH NEW ENGLAND [1034]', 'plan': 'HEALTH NEW ENGLAND CONNECTOR CARE [103102]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MGBHP COMMERCIAL HMO [267]', 'facility_id': 1011999, 'ip_expected_reimbursement': 642.07, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 71.5% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO [15000102]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP HMO MEDICARE REPLACEMENT [15000115]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MGBHP COMMERCIAL PPO [417]', 'facility_id': 1011999, 'ip_expected_reimbursement': 674.4, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 75.1% Billed', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP PPO [15000107]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': '<Self-pay>', 'facility_id': 1011999, 'ip_expected_reimbursement': 673.5, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': '', 'payer': '<Self-pay>', 'plan': '<Self-pay>', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH HPHC HMO / POS / PPO [329]', 'facility_id': 1011999, 'ip_expected_reimbursement': 702.06, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 78.18% Billed', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HPHC QUALITY LIMITED NTWK HMO [12000101]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MGB HUMANA [39]', 'facility_id': 1011999, 'ip_expected_reimbursement': 826.16, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 92% Billed', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA PPO POS [101202]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'TUFTS HEALTH PUBLIC PLANS [1013]', 'plan': 'TUFTS PUBLIC PLANS MASSHEALTH TOGETHER MCO [101302]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH BLUE CROSS INDEMNITY [318]', 'facility_id': 1011999, 'ip_expected_reimbursement': 608.66, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 67.78% Billed', 'payer': 'BLUE CROSS BLUE SHIELD [110001]', 'plan': 'BLUE CROSS MA INDEMNITY [11000104]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH UNITED HMO / PPO / INDEMNITY [280]', 'facility_id': 1011999, 'ip_expected_reimbursement': 811.7, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 90.39% Billed', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED HARVARD PILGRIM PASSPORT PPO [101602]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'COMMONWEALTH CARE ALLIANCE [1007]', 'plan': 'COMMONWEALTH CARE ALLIANCE SCO MEDICARE REPLACEMENT [100701]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HUMANA [1012]', 'plan': 'HUMANA HMO MEDICARE REPLACEMENT [101201]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'HARVARD PILGRIM [120001]', 'plan': 'HARVARD PILGRIM STRIDE MEDICARE REPLACEMENT [12000109]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': "MARTIN'S POINT [160007]", 'plan': "MARTIN'S POINT GENERATIONS ADV HMO MEDICARE REPLACEMENT [16000702]", 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MGB HEALTH PLAN [150001]', 'plan': 'MGBHP CONNECTORCARE NON MGB PCP [15000106]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH WELLSENSE MCO [333]', 'facility_id': 1011999, 'ip_expected_reimbursement': 403.2, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 44.9% Billed', 'payer': 'WELLSENSE [1003]', 'plan': 'WELLSENSE MASSHEALTH MCO [100302]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 684.28, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed', 'payer': 'TUFTS HEALTH PLAN [170001]', 'plan': 'TUFTS CARELINK PPO [17000101]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH CIGNA HMO / PPO [273]', 'facility_id': 1011999, 'ip_expected_reimbursement': 820.77, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 91.4% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA HMO POS [100602]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'SENIOR WHOLE HEALTH [1014]', 'plan': 'SENIOR WHOLE HEALTH MEDICARE REPLACEMENT [101401]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MGB CIGNA INDEMNITY [32]', 'facility_id': 1011999, 'ip_expected_reimbursement': 898.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient Indemnity PAF; 100% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA INDEMNITY [100603]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH CIGNA MEDICARE REPLACEMENT [416]', 'facility_id': 1011999, 'ip_expected_reimbursement': 619.62, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PAF; 69% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA PPO MEDICARE REPLACEMENT [100616]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICAID [254]', 'facility_id': 1011999, 'ip_expected_reimbursement': 898.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'MASSHEALTH [3001]', 'plan': 'MASSHEALTH LIMITED [300105]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH MEDICARE [434]', 'facility_id': 1011999, 'ip_expected_reimbursement': 0.0, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'No contract line matched', 'payer': 'UNITED HEALTHCARE [1016]', 'plan': 'UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACEMENT [101601]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH TUFTS HMO / PPO / CARELINK [327]', 'facility_id': 1011999, 'ip_expected_reimbursement': 684.28, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient / Outpatient PPO PAF; 76.2% Billed', 'payer': 'CIGNA [1006]', 'plan': 'CIGNA CARELINK PPO [100601]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756
# {'contractname': 'HB MVH PHCS [332]', 'facility_id': 1011999, 'ip_expected_reimbursement': 817.18, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 91% Billed', 'payer': 'PHCS MULTIPLAN [1022]', 'plan': 'GENERIC PHCS MULTIPLAN [102201]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'} score: 0.47719756

# %%
hit
# Out:
# ScoredPoint(id=93848, version=468, score=0.47719756, payload={'contractname': 'HB MVH PHCS [332]', 'facility_id': 1011999, 'ip_expected_reimbursement': 817.18, 'ip_price': 898.0, 'ip_pricing_detail': 'FSC: 48; Median of: 1', 'ip_xr_detail': 'Inpatient PAF; 91% Billed', 'payer': 'PHCS MULTIPLAN [1022]', 'plan': 'GENERIC PHCS MULTIPLAN [102201]', 'procedure_description': 'Infectious Agent Dna/Rna Influenza 1st 2 Types', 'procedurename': '30001285'}, vector=None, shard_key=None)

# %%
dfResults = pd.DataFrame([hit.payload for hit in hits])
dfResults['query_score'] = [hit.score for hit in hits]

# %%
dfResults
# Out:
#                                 contractname  facility_id  \
# 0          HB MVH HPHC HMO / POS / PPO [329]      1011999
# 1                      HB MVH MEDICARE [434]      1011999
# 2                      HB MVH MEDICARE [434]      1011999
# 3                      HB MVH MEDICARE [434]      1011999
# 4                      HB MVH MEDICARE [434]      1011999
# ..                                       ...          ...
# 295  HB MVH CIGNA MEDICARE REPLACEMENT [416]      1011999
# 296                    HB MVH MEDICAID [254]      1011999
# 297                    HB MVH MEDICARE [434]      1011999
# 298  HB MVH TUFTS HMO / PPO / CARELINK [327]      1011999
# 299                        HB MVH PHCS [332]      1011999
#
#      ip_expected_reimbursement  ip_price      ip_pricing_detail  \
# 0                        22.67      29.0      FSC: 296; BFG: 52
# 1                         0.00      30.0      FSC: 296; BFG: 52
# 2                         0.00      30.0      FSC: 296; BFG: 52
# 3                         0.00      30.0      FSC: 296; BFG: 52
# 4                         0.00      29.0      FSC: 296; BFG: 52
# ..                         ...       ...                    ...
# 295                     619.62     898.0  FSC: 48; Median of: 1
# 296                     898.00     898.0  FSC: 48; Median of: 1
# 297                       0.00     898.0  FSC: 48; Median of: 1
# 298                     684.28     898.0  FSC: 48; Median of: 1
# 299                     817.18     898.0  FSC: 48; Median of: 1
#
#                                      ip_xr_detail                       payer  \
# 0       Inpatient / Outpatient PAF; 78.18% Billed    HARVARD PILGRIM [120001]
# 1                        No contract line matched                AETNA [1001]
# 2                        No contract line matched               HUMANA [1012]
# 3                        No contract line matched  TUFTS HEALTH PLAN [170001]
# 4                        No contract line matched    UNITED HEALTHCARE [1016]
# ..                                            ...                         ...
# 295        Inpatient / Outpatient PAF; 69% Billed                CIGNA [1006]
# 296                      No contract line matched           MASSHEALTH [3001]
# 297                      No contract line matched    UNITED HEALTHCARE [1016]
# 298  Inpatient / Outpatient PPO PAF; 76.2% Billed                CIGNA [1006]
# 299                     Inpatient PAF; 91% Billed       PHCS MULTIPLAN [1022]
#
#                                                   plan  \
# 0             HPHC QUALITY LIMITED NTWK HMO [12000101]
# 1              AETNA PPO MEDICARE REPLACEMENT [100103]
# 2             HUMANA HMO MEDICARE REPLACEMENT [101201]
# 3    TUFTS MEDICARE PREFERRED HMO REPLACEMENT [1700...
# 4    UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACE...
# ..                                                 ...
# 295            CIGNA PPO MEDICARE REPLACEMENT [100616]
# 296                        MASSHEALTH LIMITED [300105]
# 297  UNITED SCO ERICKSON COMMUNITY MEDICARE REPLACE...
# 298                        CIGNA CARELINK PPO [100601]
# 299                    GENERIC PHCS MULTIPLAN [102201]
#
#                               procedure_description procedurename  query_score
# 0                        Admin of Influenza Vaccine      77100008     0.917377
# 1                        Admin of Influenza Vaccine      77100007     0.917377
# 2                        Admin of Influenza Vaccine      77100007     0.917377
# 3                        Admin of Influenza Vaccine      77100007     0.917377
# 4                        Admin of Influenza Vaccine      77100008     0.917377
# ..                                              ...           ...          ...
# 295  Infectious Agent Dna/Rna Influenza 1st 2 Types      30001285     0.477198
# 296  Infectious Agent Dna/Rna Influenza 1st 2 Types      30001285     0.477198
# 297  Infectious Agent Dna/Rna Influenza 1st 2 Types      30001285     0.477198
# 298  Infectious Agent Dna/Rna Influenza 1st 2 Types      30001285     0.477198
# 299  Infectious Agent Dna/Rna Influenza 1st 2 Types      30001285     0.477198
#
# [300 rows x 11 columns]
